# %%
import pandas as pd
from googleapiclient.discovery import build
import time

# %%
api_key =  "AIzaSyBsTeWuwvukIiZvO6NDhFy4NWk9km-jXy0"

# %%
def get_youtube_data(api_key, max_results=5000):
    youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)

    categories = ['1','2','10','17','24','25','28']
    all_data = []

    for category_id in categories:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            chart="mostPopular",
            regionCode="US",
            videoCategoryId=category_id,
            maxResults=50
        )

        response = request.execute()
        results = response.get('items', [])

        # Xử lý phân trang
        while 'nextPageToken' in response and len(results) < max_results:
            time.sleep(1)  # Chờ 1 giây giữa các yêu cầu để tránh bị chặn
            request = youtube.videos().list(
                part="snippet,contentDetails,statistics",
                chart="mostPopular",
                regionCode="US",
                videoCategoryId=category_id,
                maxResults=50,
                pageToken=response['nextPageToken']
            )
            response = request.execute()
            results.extend(response.get('items', []))

            if len(results) >= max_results:
                break

        for item in results:
            video_data = {
                'video_id'      : item['id'],
                'title'         : item['snippet']['title'],
                'description'   : item['snippet']['description'],
                'published_at'  : item['snippet']['publishedAt'],
                'channel_id'    : item['snippet']['channelId'],
                'channel_title' : item['snippet']['channelTitle'],
                'category_id'   : category_id,
                'tags'          : item['snippet'].get('tags', []),
                'duration'      : item['contentDetails']['duration'],
                'definition'    : item['contentDetails']['definition'],
                'caption'       : item['contentDetails'].get('caption', 'false'),
                'view_count'    : item['statistics'].get('viewCount', 0),
                'like_count'    : item['statistics'].get('likeCount', 0),
                'dislike_count' : item['statistics'].get('dislikeCount', 0),
                'favorite_count': item['statistics'].get('favoriteCount', 0),
                'comment_count' : item['statistics'].get('commentCount', 0),
            }
            all_data.append(video_data)

    df = pd.DataFrame(all_data)
    return df

# Lưu vào file CSV
def save_to_csv(data, filename):
  data.to_csv(filename, index=False)
  print(f"Dữ liệu đã được lưu vào {filename}")

def main():
  youtube_data = get_youtube_data(api_key, max_results=5000)
  filename = 'youtube_data.csv'
  save_to_csv(youtube_data, filename)

# %%
if __name__ == "__main__":
  main()
# Out:
# Dữ liệu đã được lưu vào youtube_data.csv

# %%
df = pd.read_csv('/content/youtube_data.csv')
df
# Out:
#          video_id                                              title  \
# 0     aK_LvKEP8dI               Oh poor Brian 😱😱😱 #familyguy #shorts
# 1     dQ4qdqOTuzg  #shorts Dog defeats black bear to save owner #...
# 2     6O1tMiUwYpk      Wolverine and Xavier came for Quicksilver...😳
# 3     -dCJB4Uyytk             We Can Use Him || Deadpool 2 #deadpool
# 4     OFUcAPOY-kA  Don’t make friends and bring them to your hous...
# ...           ...                                                ...
# 1196  HsmXlmWzemo                       火星進雙子，12星座場面大在哪| 2024/7/18直播
# 1197  4VjvYZJ1Ezo  DCS Deep Cycle Systems Defamation [Update 2] |...
# 1198  1FtZIxwhqQ0  Forget Samsung Galaxy S24 Ultra, A New MONSTER...
# 1199  rPAA-6KvURg                              My New Gaming Phone 😍
# 1200  MkTPJfHvQxs  POCO X6 PRO😈 Vs iPHONE 15 PRO💀Vs POCO F6 PRO😱 ...
#
#                                             description          published_at  \
# ...
