# %%
import pandas as pd
import numpy as np

from googleapiclient.discovery import build

# %%
youtube_data = pd.read_csv('/content/youtube_data.csv')
youtube_data
# Out:
#          video_id                                              title  \
# 0     huGd4efgdPA  Charli xcx - Guess featuring Billie Eilish (of...
# 1     SZvOmVobSVI  Team USA smashes WORLD RECORD by over a FULL S...
# 2     HUGRaSLHf8g  Shelly-Ann Fraser-Pryce & Sha'Carri Richardson...
# 3     gJannFaa9AA  Nessa Barrett - PASSENGER PRINCESS (Official M...
# 4     vF3f1tXf_yg  Houston Texans vs. Chicago Bears Highlights | ...
# ...           ...                                                ...
# 1596  HsmXlmWzemo                       火星進雙子，12星座場面大在哪| 2024/7/18直播
# 1597  4VjvYZJ1Ezo  DCS Deep Cycle Systems Defamation [Update 2] |...
# 1598  1FtZIxwhqQ0  Forget Samsung Galaxy S24 Ultra, A New MONSTER...
# 1599  rPAA-6KvURg                              My New Gaming Phone 😍
# 1600  MkTPJfHvQxs  POCO X6 PRO😈 Vs iPHONE 15 PRO💀Vs POCO F6 PRO😱 ...
#
#                                             description          published_at  \
# ...

# %%
#Check missing value
youtube_data.isnull().sum()
# Out:
# video_id            0
# title               0
# description       460
# published_at        0
# channel_id          0
# channel_title       0
# category_id         0
# tags                0
# duration            0
# definition          0
# caption             0
# view_count          0
# like_count          0
# dislike_count       0
# favorite_count      0
# comment_count       0
# dtype: int64

# %%
youtube_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        1601 non-null   object
#  1   title           1601 non-null   object
#  2   description     1141 non-null   object
#  3   published_at    1601 non-null   object
#  4   channel_id      1601 non-null   object
#  5   channel_title   1601 non-null   object
#  6   category_id     1601 non-null   int64
#  7   tags            1601 non-null   object
#  8   duration        1601 non-null   object
#  9   definition      1601 non-null   object
#  10  caption         1601 non-null   bool
#  11  view_count      1601 non-null   int64
#  12  like_count      1601 non-null   int64
#  13  dislike_count   1601 non-null   int64
#  14  favorite_count  1601 non-null   int64
#  15  comment_count   1601 non-null   int64
# dtypes: bool(1), int64(6), object(9)
# memory usage: 189.3+ KB

# %%
youtube_data['tags'].head().apply(lambda x: print(type(x)))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: tags, dtype: object

# %%
# Convert "published_at" to datetime
youtube_data['published_at'] = pd.to_datetime(youtube_data['published_at'])

# fill missing description
youtube_data['description'].fillna('No description', inplace = True)

# removing duplicates
youtube_data = youtube_data.drop_duplicates(subset = ['video_id', 'title','channel_id','published_at'], keep = "first")

# %%
api_key = 'AIzaSyBsTeWuwvukIiZvO6NDhFy4NWk9km-jXy0'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_category_mapping():
    request = youtube.videoCategories().list(
        part="snippet",
        regionCode="US"
    )
    response = request.execute()

    category_mapping = {}
    for item in response['items']:
        category_id = int(item['id'])
        category_name = item['snippet']['title']
        category_mapping[category_id] = category_name

    return category_mapping

# %%
# get the category mapping
category_mapping = get_category_mapping()
youtube_data['category'] = youtube_data['category_id'].map(category_mapping)
# Out:
# <ipython-input-10-6931940d4350>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_data['category'] = youtube_data['category_id'].map(category_mapping)

# %%
youtube_data[['view_count',	'like_count'	,'comment_count'	,'dislike_count', 'favorite_count']].describe()
# Out:
#          view_count    like_count  comment_count  dislike_count  \
# count  1.325000e+03  1.325000e+03    1325.000000         1325.0
# mean   4.278612e+06  1.778135e+05    3767.230189            0.0
# std    9.987790e+06  3.919982e+05   16549.402780            0.0
# min    1.622500e+04  0.000000e+00       0.000000            0.0
# 25%    5.044570e+05  1.688500e+04     450.000000            0.0
# 50%    1.433915e+06  5.505200e+04    1182.000000            0.0
# 75%    4.063354e+06  1.957030e+05    3092.000000            0.0
# max    2.103504e+08  8.198311e+06  378705.000000            0.0
#
#        favorite_count
# count          1325.0
# mean              0.0
# std               0.0
# min               0.0
# 25%               0.0
# 50%               0.0
# 75%               0.0
# max               0.0

# %%
youtube_data = youtube_data.drop(columns = ['video_id', 'description',
                                            'channel_id', 'category_id', 'definition','caption',
                                            'dislike_count', 'favorite_count', 'tags'])

# %%
youtube_data
# Out:
#                                                   title  \
# 0     Charli xcx - Guess featuring Billie Eilish (of...
# 1     Team USA smashes WORLD RECORD by over a FULL S...
# 2     Shelly-Ann Fraser-Pryce & Sha'Carri Richardson...
# 3     Nessa Barrett - PASSENGER PRINCESS (Official M...
# 4     Houston Texans vs. Chicago Bears Highlights | ...
# ...                                                 ...
# 1596                       火星進雙子，12星座場面大在哪| 2024/7/18直播
# 1597  DCS Deep Cycle Systems Defamation [Update 2] |...
# 1598  Forget Samsung Galaxy S24 Ultra, A New MONSTER...
# 1599                              My New Gaming Phone 😍
# 1600  POCO X6 PRO😈 Vs iPHONE 15 PRO💀Vs POCO F6 PRO😱 ...
#
#                   published_at                 channel_title    duration  \
# 0    2024-08-01 22:00:24+00:00                    Charli xcx     PT2M41S
# 1    2024-08-02 19:32:28+00:00                    NBC Sports     PT6M40S
# ...

# %%
youtube_data.to_csv('youtube_data_cleaned.csv', index = False)
